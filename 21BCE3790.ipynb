# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Download the Dataset

# %%
url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Fishing.csv"
df = pd.read_csv(url)
df.to_csv("Fishing.csv", index=False)
print("Dataset downloaded and saved as Fishing.csv")
# Out:
# Dataset downloaded and saved as Fishing.csv

# %% [markdown]
# # Module - 2

# %%
df.head()
# Out:
#    rownames     mode    price   catch   pbeach    ppier    pboat  pcharter  \
# 0         1  charter  182.930  0.5391  157.930  157.930  157.930   182.930
# 1         2  charter   34.534  0.4671   15.114   15.114   10.534    34.534
# 2         3     boat   24.334  0.2413  161.874  161.874   24.334    59.334
# 3         4     pier   15.134  0.0789   15.134   15.134   55.930    84.930
# 4         5     boat   41.514  0.1082  106.930  106.930   41.514    71.014
#
#    cbeach   cpier   cboat  ccharter     income
# 0  0.0678  0.0503  0.2601    0.5391  7083.3317
# 1  0.1049  0.0451  0.1574    0.4671  1249.9998
# 2  0.5333  0.4522  0.2413    1.0266  3749.9999
# 3  0.0678  0.0789  0.1643    0.5391  2083.3332
# 4  0.0678  0.0503  0.1082    0.3240  4583.3320

# %%
df['mode'].value_counts()
# Out:
# mode
# charter    452
# boat       418
# pier       178
# beach      134
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           rownames        price        catch       pbeach        ppier  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean    591.500000    52.081975     0.389368   103.422005   103.422005
# std     341.358316    53.829970     0.560596   103.641042   103.641042
# min       1.000000     1.290000     0.000200     1.290000     1.290000
# 25%     296.250000    15.870000     0.036100    26.656500    26.656500
# 50%     591.500000    37.896000     0.164300    74.628000    74.628000
# 75%     886.750000    67.513000     0.533300   144.144000   144.144000
# max    1182.000000   666.110000     2.310100   843.186000   843.186000
#
#              pboat     pcharter       cbeach        cpier        cboat  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean     55.256570    84.379244     0.241011     0.162224     0.171215
# std      62.713444    63.544650     0.190752     0.160390     0.209789
# ...

# %%
stacked = df.stack()
stacked
# Out:
# 0     rownames            1
#       mode          charter
#       price          182.93
#       catch          0.5391
#       pbeach         157.93
#                     ...
# 1181  cbeach         0.2537
#       cpier          0.1498
#       cboat          0.6817
#       ccharter       2.3014
#       income      6250.0013
# Length: 15366, dtype: object

# %%
stacked.unstack()
# Out:
#      rownames     mode    price   catch   pbeach    ppier    pboat pcharter  \
# 0           1  charter   182.93  0.5391   157.93   157.93   157.93   182.93
# 1           2  charter   34.534  0.4671   15.114   15.114   10.534   34.534
# 2           3     boat   24.334  0.2413  161.874  161.874   24.334   59.334
# 3           4     pier   15.134  0.0789   15.134   15.134    55.93    84.93
# 4           5     boat   41.514  0.1082   106.93   106.93   41.514   71.014
# ...       ...      ...      ...     ...      ...      ...      ...      ...
# 1177     1178     pier  150.236  0.4522  150.236  150.236  250.746  285.746
# 1178     1179    beach  235.436  0.5333  235.436  235.436  392.946  427.946
# 1179     1180     pier   65.036  0.4522   65.036   65.036  108.546  143.546
# 1180     1181    beach   36.636  0.5333   36.636   36.636   61.146   96.146
# 1181     1182     boat  235.436  0.6817   339.89   339.89  235.436  260.436
#
#       cbeach   cpier   cboat ccharter     income
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1177    False
# 1178    False
# 1179    False
# 1180    False
# 1181    False
# Length: 1182, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       rownames     mode    price   catch   pbeach    ppier    pboat  pcharter  \
# 0            1  charter  182.930  0.5391  157.930  157.930  157.930   182.930
# 1            2  charter   34.534  0.4671   15.114   15.114   10.534    34.534
# 2            3     boat   24.334  0.2413  161.874  161.874   24.334    59.334
# 3            4     pier   15.134  0.0789   15.134   15.134   55.930    84.930
# 4            5     boat   41.514  0.1082  106.930  106.930   41.514    71.014
# ...        ...      ...      ...     ...      ...      ...      ...       ...
# 1177      1178     pier  150.236  0.4522  150.236  150.236  250.746   285.746
# 1178      1179    beach  235.436  0.5333  235.436  235.436  392.946   427.946
# 1179      1180     pier   65.036  0.4522   65.036   65.036  108.546   143.546
# 1180      1181    beach   36.636  0.5333   36.636   36.636   61.146    96.146
# 1181      1182     boat  235.436  0.6817  339.890  339.890  235.436   260.436
#
# ...

# %%
df.isnull()
# Out:
#       rownames   mode  price  catch  pbeach  ppier  pboat  pcharter  cbeach  \
# 0        False  False  False  False   False  False  False     False   False
# 1        False  False  False  False   False  False  False     False   False
# 2        False  False  False  False   False  False  False     False   False
# 3        False  False  False  False   False  False  False     False   False
# 4        False  False  False  False   False  False  False     False   False
# ...        ...    ...    ...    ...     ...    ...    ...       ...     ...
# 1177     False  False  False  False   False  False  False     False   False
# 1178     False  False  False  False   False  False  False     False   False
# 1179     False  False  False  False   False  False  False     False   False
# 1180     False  False  False  False   False  False  False     False   False
# 1181     False  False  False  False   False  False  False     False   False
#
#       cpier  cboat  ccharter  income
# ...

# %%
df.isnull().sum()
# Out:
# rownames    0
# mode        0
# price       0
# catch       0
# pbeach      0
# ppier       0
# pboat       0
# pcharter    0
# cbeach      0
# cpier       0
# cboat       0
# ccharter    0
# income      0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.count()
# Out:
# rownames    1182
# mode        1182
# price       1182
# catch       1182
# pbeach      1182
# ppier       1182
# pboat       1182
# pcharter    1182
# cbeach      1182
# cpier       1182
# cboat       1182
# ccharter    1182
# income      1182
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# rownames    0
# mode        0
# price       0
# catch       0
# pbeach      0
# ppier       0
# pboat       0
# pcharter    0
# cbeach      0
# cpier       0
# cboat       0
# ccharter    0
# income      0
# dtype: int64

# %%
mean_view = df.price
mean_view.mean()
# Out:
# 52.08197461928934

# %%
bins = [50, 100, 150, 200, 250, 300, 350, 400] 
column_to_bin = "price" 
category = pd.cut(df[column_to_bin], bins)

# %%
pd.value_counts(category)
# Out:
# C:\Users\KSHIT\AppData\Local\Temp\ipykernel_6292\2654243906.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# price
# (50, 100]     293
# (100, 150]     79
# (150, 200]     34
# (200, 250]     19
# (250, 300]      5
# (300, 350]      4
# (350, 400]      1
# Name: count, dtype: int64

# %%
TotalPrice = df["price"]
TotalPrice[np.abs(TotalPrice) > 300]
# Out:
# 211    387.208
# 249    666.110
# 343    306.820
# 377    328.432
# 446    335.314
# 588    330.072
# Name: price, dtype: float64

# %% [markdown]
# # Module - 3

# %%
df.dtypes
# Out:
# rownames      int64
# mode         object
# price       float64
# catch       float64
# pbeach      float64
# ppier       float64
# pboat       float64
# pcharter    float64
# cbeach      float64
# cpier       float64
# cboat       float64
# ccharter    float64
# income      float64
# dtype: object

# %%
df['price'] = df['price'].astype(str)
print(df['price'].str.isnumeric().value_counts())
# Out:
# price
# False    1182
# Name: count, dtype: int64

# %%
df['price'].loc[df['price'].str.isnumeric() == False]
# Out:
# 0        182.93
# 1        34.534
# 2        24.334
# 3        15.134
# 4        41.514
#          ...
# 1177    150.236
# 1178    235.436
# 1179     65.036
# 1180     36.636
# 1181    235.436
# Name: price, Length: 1182, dtype: object

# %%
df["price"] = pd.to_numeric(df["price"])
mean = df["price"].mean()
median =df["price"].median()
mode = df["price"].mode()
print(mean , median, mode)
# Out:
# 52.08197461928934 37.896 0    12.87
# Name: price, dtype: float64

# %%
df.price.value_counts().nlargest(30).plot(kind='bar', figsize=(10,6))
plt.title("Number of boats by price")
plt.ylabel('Number of Boats')
plt.xlabel('Price of the boats')
# Out:
# Text(0.5, 0, 'Price of the boats')

# %%
sns.boxplot(x="price",data=df)
plt.show()

# %%
plt.scatter(df["price"], df["pboat"])
plt.title("Scatter Plot for pboat vs price")
plt.xlabel("pboat")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
sns.boxplot(x="mode",y="price",data=df)
plt.show()

# %%
sns.pairplot(df,vars = ['catch', 'price','pboat'], kind="reg")
plt.show()

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars = ['catch', 'price','pboat'], hue="mode")
plt.show()

# %%
from scipy import stats

corr = stats.pearsonr(df["price"], df["pboat"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 4.614486189682653e-134
# cor:		 0.634315465346139

# %%
correlation = df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#           rownames     price     catch    pbeach     ppier     pboat  \
# rownames  1.000000 -0.205256  0.311533 -0.098860 -0.098860  0.078949
# price    -0.205256  1.000000  0.106920  0.403692  0.403692  0.634315
# catch     0.311533  0.106920  1.000000 -0.026106 -0.026106 -0.005323
# pbeach   -0.098860  0.403692 -0.026106  1.000000  1.000000  0.111820
# ppier    -0.098860  0.403692 -0.026106  1.000000  1.000000  0.111820
# pboat     0.078949  0.634315 -0.005323  0.111820  0.111820  1.000000
# pcharter  0.073141  0.637275 -0.008625  0.141024  0.141024  0.996255
# cbeach    0.118603  0.034230  0.194224  0.331906  0.331906  0.213464
# cpier     0.126478  0.006900  0.163169  0.226081  0.226081  0.252776
# cboat     0.354635 -0.050906  0.743612 -0.098206 -0.098206 -0.041346
# ccharter  0.355020 -0.019656  0.789652 -0.027385 -0.027385 -0.022604
# income   -0.092054  0.315275 -0.082716  0.526819  0.526819  0.320198
#
#           pcharter    cbeach     cpier     cboat  ccharter    income
# ...

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
# Out:
# <Axes: >

# %% [markdown]
# # Module - 5

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
X = df[['price', 'income']]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.grid(True)
plt.show()
# Out:
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# c:\Users\KSHIT\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
X = df[['price', 'income']].to_numpy()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=100, c='blue', label='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=100, c='green', label='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=100, c='cyan', label='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=100, c='magenta', label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            s=300, c='yellow', label='Centroids', edgecolors='black')

plt.title('Clusters of Fishing Data')
plt.xlabel('Price')
plt.ylabel('Income')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.title("Annual Income Distribution", fontsize=16)
plt.xlabel("Income", fontsize=14)
plt.grid(True)
plt.hist(df['income'], color='orange', edgecolor='k')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Income Distribution", fontsize=16)
plt.xlabel("Income", fontsize=14)
plt.grid(True)
plt.hist(df['income'], color='green', edgecolor='k')
plt.show()

# %%
import scipy.cluster.hierarchy as sch

# %%
X = df[['price', 'income']].values

# %%
plt.figure(figsize=(15,6))
plt.title('Dendrogram')
plt.xlabel('Data points')
plt.ylabel('Euclidean distances')

dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')

plt.hlines(y=40000, xmin=0, xmax=20000, lw=3, linestyles='--', color='red')
plt.text(x=900, y=42000, s='Horizontal line at 40,000', fontsize=12, color='red')

dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))
plt.show()

# %% [markdown]
# # Module - 7

# %%
sns.set(style="ticks", color_codes=True)
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 150

# %%
print(df.keys())
# Out:
# Index(['rownames', 'mode', 'price', 'catch', 'pbeach', 'ppier', 'pboat',
#        'pcharter', 'cbeach', 'cpier', 'cboat', 'ccharter', 'income'],
#       dtype='object')

# %%
df.head()
print(df.columns)
print(df.head())
# Out:
# Index(['rownames', 'mode', 'price', 'catch', 'pbeach', 'ppier', 'pboat',
#        'pcharter', 'cbeach', 'cpier', 'cboat', 'ccharter', 'income'],
#       dtype='object')
#    rownames     mode    price   catch   pbeach    ppier    pboat  pcharter  \
# 0         1  charter  182.930  0.5391  157.930  157.930  157.930   182.930
# 1         2  charter   34.534  0.4671   15.114   15.114   10.534    34.534
# 2         3     boat   24.334  0.2413  161.874  161.874   24.334    59.334
# 3         4     pier   15.134  0.0789   15.134   15.134   55.930    84.930
# 4         5     boat   41.514  0.1082  106.930  106.930   41.514    71.014
#
#    cbeach   cpier   cboat  ccharter     income
# 0  0.0678  0.0503  0.2601    0.5391  7083.3317
# 1  0.1049  0.0451  0.1574    0.4671  1249.9998
# 2  0.5333  0.4522  0.2413    1.0266  3749.9999
# 3  0.0678  0.0789  0.1643    0.5391  2083.3332
# 4  0.0678  0.0503  0.1082    0.3240  4583.3320

# %%
df.isna().sum()
# Out:
# rownames    0
# mode        0
# price       0
# catch       0
# pbeach      0
# ppier       0
# pboat       0
# pcharter    0
# cbeach      0
# cpier       0
# cboat       0
# ccharter    0
# income      0
# dtype: int64

# %%
df_numeric = df.select_dtypes(include=['number'])  # Keep only numeric columns
sns.heatmap(df_numeric.corr(), square=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
sns.lmplot(x='price', y='income', data=df)

# %%
X = df[['price']]
y = df[['income']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.score(X_test, y_test)
# Out:
# 0.02434064360985666

# %%
y_pred=regressor.predict(X_test)
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#        Actual    Predicted
# 0  3749.99990  3429.385145
# 1  5416.66670  3511.445389
# 2  4583.33200  3319.868912
# 3  3749.99990  3856.782247
# 4  8750.00100  3791.373394
# 5  4583.33200  5427.517882
# 6   416.66668  3349.068682
# 7  7916.66630  3740.085742
# 8  3749.99990  3973.478751
# 9  3749.99990  3809.221497

# %%
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"MAE score: {mean_absolute_error(y_test, y_pred)}")
print(f"MSE score: {mean_squared_error(y_test, y_pred)}")
# Out:
# R2 score: 0.02434064360985666
# MAE score: 1774.543209008099
# MSE score: 5488822.665214012
